# %% [markdown]
# # Day 4: 09/03/2026

# %% [markdown]
# ## print statement

# %%
print("Hello","Day 4","Monday","2026")
# Out:
# Hello Day 4 Monday 2026

# %%
print("Hello","Day 4","Monday","2026")
print("Hello World")
# Out:
# Hello Day 4 Monday 2026
# Hello World

# %%
print("Hello","Day 4","Monday","2026",end = "\n")
print("Hello World")
# Out:
# Hello Day 4 Monday 2026
# Hello World

# %%
print("Hello","Day 4","Monday","2026",end ="|")
print("Hello Monday 2026")
# Out:
# Hello Day 4 Monday 2026|Hello Monday 2026

# %% [markdown]
# ## Variables

# %%
hello ="Prakhar"
World ="world"
World = hello
hello ="Bye"
print(hello,World)
# Out:
# Bye Prakhar

# %%
name = input("Your Name: ")
age = input("Your Age: ")
print("Hello",name,"your age is",age)
# Out:
# Your Name:  Prakhar
# Your Age:  23
# Hello Prakhar your age is 23

# %% [markdown]
# ## Arithematic Operators

# %%
x = 1
y = 7.1
result = x + y
print(result)
# Out:
# 8.1

# %%
x = 1
y = 7.1
result = x / y
print(result)
# Out:
# 0.14084507042253522

# %%
x = 1
y = 7.1
result = x // y
print(result)
# Out:
# 0.0

# %%
x = 1
y = 7
result = x / y
print(result)
# Out:
# 0.14285714285714285

# %%
x = 1
y = 7
result = x // y
print(result)
# Out:
# 0

# %%
x = 1
y = 7
result = int(x / y)
print(result)
# Out:
# 0

# %%
x = 1
y = 7
result = x ** y
print(result)
# Out:
# 1

# %%
x = 8
y = 7
result = x % y
print(result)
# Out:
# 1

# %%
x = 1
y = 7
result = (x / y) * 9
print(result)
# Out:
# 1.2857142857142856

# %%
num = input("Number: ")
print(int(num) - 8)
# Out:
# Number:  9
# 1

# %%
num = input("Number: ")
print(float(num) - 8)
# Out:
# Number:  10
# 2.0

# %% [markdown]
# ## String Methods

# %%
var = "Hello"
print(type(var))
# Out:
# <class 'str'>

# %%
var = "hello".upper()
print(var)
# Out:
# HELLO

# %%
var = "hello"
print(var.upper())
# Out:
# HELLO

# %%
var = "heLLO"
print(var.lower())
# Out:
# hello

# %%
var = "hello"
print(var.capitalize())
# Out:
# Hello

# %%
var = "hello world"
print(var.capitalize())
# Out:
# Hello world

# %%
var = "heLL0 world"
print(var.count("ll"))
# Out:
# 0

# %%
var = "heLLo world"
print(var.lower().count("ll"))
# Out:
# 1
